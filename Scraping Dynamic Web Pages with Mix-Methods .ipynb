# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#What-Is-Web-Scraping?" data-toc-modified-id="What-Is-Web-Scraping?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>What Is Web Scraping?</a></span></li><li><span><a href="#How-To-Inspect-The-Web-Site" data-toc-modified-id="How-To-Inspect-The-Web-Site-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>How To Inspect The Web Site</a></span></li><li><span><a href="#What-Is-Dynamic-Web-Sites" data-toc-modified-id="What-Is-Dynamic-Web-Sites-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>What Is Dynamic Web Sites</a></span></li><li><span><a href="#Downloading-HTML-Pages" data-toc-modified-id="Downloading-HTML-Pages-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Downloading HTML Pages</a></span></li><li><span><a href="#Static-Web-Scraping-With-Python-Using-BeautifulSoup" data-toc-modified-id="Static-Web-Scraping-With-Python-Using-BeautifulSoup-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Static Web Scraping With Python Using BeautifulSoup</a></span><ul class="toc-item"><li><span><a href="#Extract-Data-From-a-Single-Element" data-toc-modified-id="Extract-Data-From-a-Single-Element-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Extract Data From a Single Element</a></span></li><li><span><a href="#Selecting-Nested-Elements" data-toc-modified-id="Selecting-Nested-Elements-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Selecting Nested Elements</a></span></li><li><span><a href="#Looking-for-Hidden-Elements" data-toc-modified-id="Looking-for-Hidden-Elements-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Looking for Hidden Elements</a></span></li><li><span><a href="#Get-Data-From-a-Table" data-toc-modified-id="Get-Data-From-a-Table-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Get Data From a Table</a></span><ul class="toc-item"><li><span><a href="#Getting-The-All-Products-From-All-Pages" data-toc-modified-id="Getting-The-All-Products-From-All-Pages-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Getting The All Products From All Pages</a></span></li><li><span><a href="#Getting-The-All-Products-From-All-Pages-As-Table" data-toc-modified-id="Getting-The-All-Products-From-All-Pages-As-Table-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>Getting The All Products From All Pages As Table</a></span></li><li><span><a href="#Getting-The-All-Products-From-All-Pages-As-Data-Frame" data-toc-modified-id="Getting-The-All-Products-From-All-Pages-As-Data-Frame-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>Getting The All Products From All Pages As Data Frame</a></span></li></ul></li></ul></li><li><span><a href="#Dynamic-Web-Page-Scraping-With-Python" data-toc-modified-id="Dynamic-Web-Page-Scraping-With-Python-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Dynamic Web Page Scraping With Python</a></span><ul class="toc-item"><li><span><a href="#What-Is-a-Dynamic-Website?" data-toc-modified-id="What-Is-a-Dynamic-Website?-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>What Is a Dynamic Website?</a></span></li><li><span><a href="#Intercept-Network-Fetch/XHR-Requests" data-toc-modified-id="Intercept-Network-Fetch/XHR-Requests-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Intercept Network Fetch/XHR Requests</a></span></li><li><span><a href="#Scrape-the-First-Few-Data" data-toc-modified-id="Scrape-the-First-Few-Data-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Scrape the First Few Data</a></span></li><li><span><a href="#Simulate-the-Network-API-Call" data-toc-modified-id="Simulate-the-Network-API-Call-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Simulate the Network API Call</a></span></li></ul></li><li><span><a href="#Scraping-Dynamic-Web-Pages-in-Python-Using-Selenium" data-toc-modified-id="Scraping-Dynamic-Web-Pages-in-Python-Using-Selenium-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Scraping Dynamic Web Pages in Python Using Selenium</a></span><ul class="toc-item"><li><span><a href="#Selecting-Elements-in-Selenium" data-toc-modified-id="Selecting-Elements-in-Selenium-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Selecting Elements in Selenium</a></span></li><li><span><a href="#How-to-Scrape-Infinite-Scroll-Web-Pages-With-Selenium" data-toc-modified-id="How-to-Scrape-Infinite-Scroll-Web-Pages-With-Selenium-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>How to Scrape Infinite Scroll Web Pages With Selenium</a></span></li></ul></li></ul></div>

# %%
#pip install prettytable
# Out:
# ...
#   Obtaining dependency information for prettytable from https://files.pythonhosted.org/packages/93/65/461ab13c4d877d428d046c75576c6877381580fe3cdb8fd8231e402f5cac/prettytable-3.13.0-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # What Is Web Scraping?

# %% [markdown]
# Web scraping is the process of retrieving data from the web. Even copying and pasting content from a page is a form of scraping.
# If you practice scraping responsibly, you're unlikely to run into legal issues. Just make sure that you're not violating the Terms of Service or extracting sensitive information, especially before building a large-scale project.
#
# Web Scrape Fields:
#  1. Competitor Analysis
#  2. Price Comparison
#  3. Lead Generation
#  4. Sentiment Analysis
#  5. Social Media Analytics
#  6. Product Prices
#  7. Real Estate Listings
#  8. Weather Data
#  9. Sports Statistics

# %% [markdown]
# # How To Inspect The Web Site

# %% [markdown]
# All modern browsers come with a suite of advanced developer tools, most offering nearly the same. These enable you to explore the HTML code of a web page and play with it.
# To see the Developer Tools;
# - Right-click on an HTML element and select Inspect to open the DevTools window or,
# - Click the top-right ⋮ menu button, and select the More Tools > Developer toolsoption(for windows/linux).
# This lets you inspect the structure of the Document Object Model (DOM) of a web page. So, you can gain deeper insight into the source code. The DOM represents a document with a logical tree. Each branch of the tree ends in a node, and each node contains objects. DOM methods allow programmatic access to the tree. With them, you can change the document's structure, style, or content.
# In the DevTools section, enter the Elements tab to access the DOM.

# %% [markdown]
# # What Is Dynamic Web Sites

# %% [markdown]
# **Satic Web Sites;**
# - The HTML source code contains all the content you see on the page.
# - You can typically use simple HTTP requests (like with the requests library in Python) to fetch the HTML and then parse it with libraries like Beautiful Soup to extract data.
# - To check that, take a look at the FETCH/XHR section in DevTools' Network tab. Reload the page, and that section should remain empty. This means that the target page doesn't make AJAX calls to retrieve data at render time. Thus, what you get from the server is what you see on the page.
#
# **Dynamic Websites;**
# - Content is loaded by JavaScript. The initial HTML might be minimal, and JavaScript code is executed in the browser to fetch and render the content dynamically. Simply fetching the HTML source code won't give you the complete content because it's generated after the page loads.
# - Dynamic websites often use **AJAX (Asynchronous JavaScript and XML)** to load data in the background without requiring a full page reload. Your scraper needs to intercept these requests to get the data.
# - They don't have all its content directly in static HTML. A web Site displays data on the fly using server-side or client-side rendering or based on the user's actions, such as showing more content as the user clicks a button or scrolls down the page (infinite scrolling).
# - This approach improves user experience by providing relevant content without reloading the entire page. One way to determine if a website is dynamic is to disable JavaScript in your browser's command palette. If the website is dynamic, most or all of its content will disappear.
# - Not all dynamic pages are the same. Some fetch content from **application programming interfaces (APIs)**, which you can observe through the DevTools' Network tab. Others use client-side rendering to load content directly from **JSON objects** stored within the **DOM (Document Object Model)**.

# %% [markdown]
# # Downloading HTML Pages

# %%
import requests

# download the HTML document
# with an HTTP GET request
response = requests.get("https://www.scrapingcourse.com/ecommerce/")

#if run response and # if the output of the response is 200, everything is ok. 

#print the HTML code
print(response.text)
# Out:
# <!doctype html>
# <html lang="en-US">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <link rel="profile" href="https://gmpg.org/xfn/11">
# <link rel="pingback" href="https://www.scrapingcourse.com/ecommerce/xmlrpc.php">
# <!-- Google tag (gtag.js) -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-NZGD14H87G"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
# 	gtag('config', 'G-NZGD14H87G');
# </script>
# <title>Ecommerce Test Site to Learn Web Scraping &#8211; ScrapingCourse.com</title>
# <meta name='robots' content='max-image-preview:large' />
# <link rel='dns-prefetch' href='//stats.wp.com' />
# <link rel='dns-prefetch' href='//www.scrapingcourse.com' />
# <link rel='dns-prefetch' href='//fonts.googleapis.com' />
# ...

# %% [markdown]
# # Static Web Scraping With Python Using BeautifulSoup

# %% [markdown]
# In the previous step, you retrieved an HTML document from the server. If you take a look at it, you'll see a long string of code, and the only way to make sense of it is by **extracting the desired data through HTML parsing.**

# %%
import requests 
from bs4 import BeautifulSoup 
import pandas as pd

# %%
#response = requests.get(target_url)
soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# - The BeautifulSoup() constructor takes some content and a string that specifies the parser to use. "html.parser" instructs Beautiful Soup to use the HTML one.
#
# - **Common error:** Passing response.text instead of response.content to BeautifulSoup().

# %% [markdown]
# - The content attribute of the response object holds the HTML data in raw bytes, which is easier to decode than the text representation stored in the text attribute. To avoid issues with character encoding, prefer response.content to response.text with BeautifulSoup().

# %% [markdown]
# - To be noted, websites contain data in many formats. Individual elements, lists, and tables are just a few examples. If you want your Python scraper to be effective, you need to know how to use Beautiful Soup in many scenarios. Let's see how to solve the most common challenges!

# %% [markdown]
# ## Extract Data From a Single Element

# %% [markdown]
# - Beautiful Soup offers several ways to select HTML elements from the DOM, with the id field being the most effective approach to selecting a single element. As its name suggests, the id uniquely identifies an HTML node on the page.

# %% [markdown]
#  - You can use this information to select the product search element

# %%
product_search_element = soup.find(id="woocommerce-product-search-field-0")
product_search_element
# Out:
# <input class="search-field" data-form="input" data-testid="product-search-field" id="woocommerce-product-search-field-0" name="s" placeholder="Search products…" type="search" value=""/>

# %% [markdown]
# - The find() function enables you to extract a single HTML element from the **DOM.**
#
# - Keep in mind that id is an optional attribute. That's why there are also other approaches to selecting elements

# %%
# get the first <h1> element on the page
h1_element = soup.find("h1")
h1_element
# Out:
# <h1 class="woocommerce-products-header__title page-title" data-header="title" data-testid="page-title" id="page-title">Shop</h1>

# %% [markdown]
# - By attribute: through to the attrs parameter in find()

# %%
# find the first element on the page with the name="s" HTML attribute
search_input_element = soup.find(attrs={"name": "s"})
search_input_element
# Out:
# <input class="search-field" data-form="input" data-testid="product-search-field" id="woocommerce-product-search-field-0" name="s" placeholder="Search products…" type="search" value=""/>

# %% [markdown]
# - You can also retrieve HTML nodes by CSS selector with select() and select_one()

# %%
# find the first element identified by the "input.search-field" CSS selector
search_input_element = soup.select_one("input.search-field")
search_input_element
# Out:
# <input class="search-field" data-form="input" data-testid="product-search-field" id="woocommerce-product-search-field-0" name="s" placeholder="Search products…" type="search" value=""/>

# %% [markdown]
# - On text content HTML elements, extract their text with get_text()

# %%
h1_title = soup.select_one(".beta.site-title").getText()
print(h1_title)
# Out:
# Ecommerce Test Site to Learn Web Scraping

# %%
product_elements = soup.select("li.product")# soup.find_all('li', {'class': 'product'})

# %% [markdown]
# - soup.select("li.product"): This method uses CSS selectors to find all \<li> elements with the class "product". It's very similar to how you would select elements in a CSS file or using JavaScript's querySelectorAll().
# - soup.find_all('li', {'class': 'product'}): This method uses a combination of tag name and dictionary to specify attributes. It finds all \<li> elements that have a class attribute of "product" and will be used below.
# - While both approaches achieve the same result, soup.select can be more intuitive if you're familiar with CSS selectors, and soup.find_all might be more flexible for more complex queries.

# %%
# the list of dictionaries containing the
# scrape data
products = []

for product_element in product_elements:
    name = product_element.find("h2").get_text()
    url = product_element.find("a")["href"]
    image = product_element.find("img")["src"]
    price = product_element.select_one(".amount").get_text()

    # define a dictionary with the scraped data
    new_product = {
        "name": name,
        "url": url,
        "image": image,
        "price": price
    }
    # add the new product dictionary to the list
    products.append(new_product)
# Out:
# [{'name': 'Abominable Hoodie',
#   'url': 'https://www.scrapingcourse.com/ecommerce/product/abominable-hoodie/',
#   'image': 'https://www.scrapingcourse.com/ecommerce/wp-content/uploads/2024/03/mh09-blue_main.jpg',
#   'price': '$69.00'},
#  {'name': 'Adrienne Trek Jacket',
#   'url': 'https://www.scrapingcourse.com/ecommerce/product/adrienne-trek-jacket/',
#   'image': 'https://www.scrapingcourse.com/ecommerce/wp-content/uploads/2024/03/wj08-gray_main.jpg',
#   'price': '$57.00'},
#  {'name': 'Aeon Capri',
#   'url': 'https://www.scrapingcourse.com/ecommerce/product/aeon-capri/',
#   'image': 'https://www.scrapingcourse.com/ecommerce/wp-content/uploads/2024/03/wp07-black_main.jpg',
#   'price': '$48.00'},
#  {'name': 'Aero Daily Fitness Tee',
#   'url': 'https://www.scrapingcourse.com/ecommerce/product/aero-daily-fitness-tee/',
#   'image': 'https://www.scrapingcourse.com/ecommerce/wp-content/uploads/2024/03/ms01-blue_main.jpg',
#   'price': '$24.00'},
# ...

# %%
# Find all classes within the <li> element
li_element = soup.find('li')

if li_element:
    classes = li_element.get('class')
    print(classes)
else:
    print("The <li> element was not found.")
# Out:
# ['menu-item', 'menu-item-type-post_type', 'menu-item-object-page', 'menu-item-home', 'current-menu-item', 'current_page_item', 'menu-item-2829']

# %%
# Find all product items
products = soup.find_all('li', {'class': 'product'})
products
# Out:
# [<li class="product type-product post-246 status-publish first outofstock product_cat-hoodies-sweatshirts has-post-thumbnail shipping-taxable purchasable product-type-variable" data-products="item" itemscope="" itemtype="http://schema.org/Product">
# ...

# %%
# An alternative way for finding all product items
#products = soup.find_all('li', {'data-products': 'item'})
#products = soup.find_all('li', {'itemtype': 'http://schema.org/Product'})

# %%
# Find all product names
product_names = [name.get_text() for name in soup.find_all('h2', class_='product-name')]
product_names
# Out:
# ['Abominable Hoodie',
#  'Adrienne Trek Jacket',
#  'Aeon Capri',
#  'Aero Daily Fitness Tee',
#  'Aether Gym Pant',
#  'Affirm Water Bottle',
#  'Aim Analog Watch',
#  'Ajax Full-Zip Sweatshirt',
#  'Ana Running Short',
#  'Angel Light Running Short',
#  'Antonia Racer Tank',
#  'Apollo Running Short',
#  'Arcadio Gym Short',
#  'Argus All-Weather Tank',
#  'Ariel Roll Sleeve Sweatshirt',
#  'Artemis Running Short']

# %%
# Find all prices
prices = [price.get_text() for price in soup.find_all('span', class_='product-price')]
prices
# Out:
# ['$0.00',
#  '$69.00',
#  '$57.00',
#  '$48.00',
#  '$24.00',
#  '$74.00',
#  '$7.00',
#  '$45.00',
#  '$69.00',
#  '$40.00',
#  '$42.00',
#  '$34.00',
#  '$32.50',
#  '$20.00',
#  '$22.00',
#  '$39.00',
#  '$45.00']

# %%
# Iterate through each product to extract the name and price
for product in products: # or product_alt
    name = product.find('h2', {'class': 'product-name'}).text #{'class': 'woocommerce-loop-product__title'}
    price = product.find('span', {'class': 'amount'}).text #{'data-products': 'price'}, {'class': 'woocommerce-Price'}, {'data-testid': 'product-price'}
    print(f'Product Name: {name}, Price: {price}')
# Out:
# Product Name: Abominable Hoodie, Price: $69.00
# Product Name: Adrienne Trek Jacket, Price: $57.00
# Product Name: Aeon Capri, Price: $48.00
# Product Name: Aero Daily Fitness Tee, Price: $24.00
# Product Name: Aether Gym Pant, Price: $74.00
# Product Name: Affirm Water Bottle, Price: $7.00
# Product Name: Aim Analog Watch, Price: $45.00
# Product Name: Ajax Full-Zip Sweatshirt, Price: $69.00
# Product Name: Ana Running Short, Price: $40.00
# Product Name: Angel Light Running Short, Price: $42.00
# Product Name: Antonia Racer Tank, Price: $34.00
# Product Name: Apollo Running Short, Price: $32.50
# Product Name: Arcadio Gym Short, Price: $20.00
# Product Name: Argus All-Weather Tank, Price: $22.00
# Product Name: Ariel Roll Sleeve Sweatshirt, Price: $39.00
# Product Name: Artemis Running Short, Price: $45.00

# %% [markdown]
# ## Selecting Nested Elements

# %% [markdown]
# - The DOM is a nested tree structure. Defining a selection strategy to get the desired HTML elements in one step isn't always easy, but that's why Beautiful Soup offers an alternative approach for searching nodes.
#
# - First, select the parent containing many nested nodes. Next, call the Beautiful Soup search functions directly on this one. This will limit the scope of research only to the children of the parent element.
#
# - Let's dig into this with an example!
#
# - Assume you want to retrieve some data from the first product (Abominable Hoodie). By inspecting it, you'll see that its HTML elements don't have an ID. This means that you can't access them directly, and you need a complex CSS selector.

# %%
parent_element = soup.find(class_="post-246") # Extracting First Product Information from List Element-Abominable Hoodie
# extracting data from the nested nodes
# inside the parent element
image_url = parent_element.find("img")["src"]
price = parent_element.select_one(".price").get_text()
currency_symbol = parent_element.select_one('.woocommerce-Price-currencySymbol').text
print(image_url)
print(price)
print(currency_symbol)
# Out:
# https://www.scrapingcourse.com/ecommerce/wp-content/uploads/2024/03/mh09-blue_main.jpg
# $69.00
# $

# %%
parent_element
# Out:
# <li class="product type-product post-246 status-publish first outofstock product_cat-hoodies-sweatshirts has-post-thumbnail shipping-taxable purchasable product-type-variable" data-products="item" itemscope="" itemtype="http://schema.org/Product">
# ...

# %% [markdown]
# - Get the page URL and complete name related to the second (Adrienne Trek Jacket) product.

# %%
second_product_element = soup.find(class_="post-1864")
product_url = second_product_element.find("a")["href"]
product_name = second_product_element.find("h2").get_text()
product_price = second_product_element.select_one(".price").get_text()
print(product_url)
print(product_name)
print(product_price)
# Out:
# https://www.scrapingcourse.com/ecommerce/product/adrienne-trek-jacket/
# Adrienne Trek Jacket
# $57.00

# %% [markdown]
# ## Looking for Hidden Elements

# %% [markdown]
# - HTML elements with the **display:none** or **visibility:hidden** CSS properties are not visible to users. Since the browser doesn't render them on the page, they are referred to as hidden elements.
# - Typically, these contain data to show only after a particular interaction. Also, they allow web developers to store information that shouldn't be visible to the end user. This information is often used to provide additional functionality to the page or for debugging.
# - They're still part of the DOM. Thus, you can select and scrape data from them as from all other HTML elements.

# %%
response_hidden = requests.get("https://www.scrapingcourse.com/ecommerce/product/abominable-hoodie/")
soup_hid = BeautifulSoup(response_hidden.content, "html.parser")

additional_info_div = soup_hid.select_one(".woocommerce-Tabs-panel--additional_information")
#additional_info_div = soup_find(id = "tab-additional_information")

# %%
print(additional_info_div.prettify())
# Out:
# <div aria-labelledby="tab-title-additional_information" class="woocommerce-Tabs-panel woocommerce-Tabs-panel--additional_information panel entry-content wc-tab" id="tab-additional_information" role="tabpanel">
#  <h2>
#   Additional information
#  </h2>
#  <table class="woocommerce-product-attributes shop_attributes">
#   <tr class="woocommerce-product-attributes-item woocommerce-product-attributes-item--attribute_size">
#    <th class="woocommerce-product-attributes-item__label">
#     Size
#    </th>
#    <td class="woocommerce-product-attributes-item__value">
#     <p>
#      XS, S, M, L, XL
#     </p>
#    </td>
#   </tr>
#   <tr class="woocommerce-product-attributes-item woocommerce-product-attributes-item--attribute_color">
#    <th class="woocommerce-product-attributes-item__label">
#     Color
#    </th>
#    <td class="woocommerce-product-attributes-item__value">
#     <p>
#      Blue, Green, Red
#     </p>
#    </td>
#   </tr>
#  </table>
# </div>

# %% [markdown]
# That's precisely the HTML code contained in the "Additional Information" <div>. Since the result isn't None, Beautiful Soup was able to find it even though it's a hidden element.

# %% [markdown]
# ## Get Data From a Table

# %% [markdown]
# - An HTML table is a structured set of data that consists of several \<tr> rows and many \<td> cells. Retrieve all information

# %%
# get the table contained inside the "Additional Information" div
additional_info_table = additional_info_div.find("table")

# iterate over each row of the table
for row in additional_info_table.find_all("tr"):
    category_name = row.find("th").get_text()
    cell_value = row.find("td").get_text()
    print(category_name, cell_value)
# Out:
# Size XS, S, M, L, XL
#
# Color Blue, Green, Red

# %% [markdown]
# ### Getting The All Products From All Pages

# %%
# Loop through 12 pages
for page_num in range(1, 13):
    url = f"https://www.scrapingcourse.com/ecommerce/page/{page_num}/"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    products = soup.find_all('li', {'class': 'product'})
    for product in products:
        name = product.find('h2', {'class': 'product-name'}).text
        url_product = product.find('a', href=True)['href']
        price = product.find('span', {'class': 'amount'}).text

        # Fetch hidden elements (size and color) for each product
        response_hidden = requests.get(url_product)
        soup_hid = BeautifulSoup(response_hidden.content, "html.parser")

        additional_info_div = soup_hid.select_one(".woocommerce-Tabs-panel--additional_information")
        
        size = "Not available"
        color = "Not available"
        
        if additional_info_div:
            size_info = additional_info_div.find("tr", {'class': 'woocommerce-product-attributes-item--attribute_size'})
            color_info = additional_info_div.find("tr", {'class': 'woocommerce-product-attributes-item--attribute_color'})
            
            if size_info:
                size = size_info.find('td').text.strip()
            if color_info:
                color = color_info.find('td').text.strip()

        print(f'Page: {page_num}, Product Name: {name}, Price: {price}, Size: {size}, Color: {color}')
# Out:
# Page: 1, Product Name: Abominable Hoodie, Price: $69.00, Size: XS, S, M, L, XL, Color: Blue, Green, Red
# Page: 1, Product Name: Adrienne Trek Jacket, Price: $57.00, Size: XS, S, M, L, XL, Color: Gray, Orange, Purple
# Page: 1, Product Name: Aeon Capri, Price: $48.00, Size: 28, 29, Color: Black, Blue, Orange
# Page: 1, Product Name: Aero Daily Fitness Tee, Price: $24.00, Size: XS, S, M, L, XL, Color: Black, Brown, Yellow
# Page: 1, Product Name: Aether Gym Pant, Price: $74.00, Size: 32, 33, 34, 36, Color: Blue, Brown, Green
# Page: 1, Product Name: Affirm Water Bottle, Price: $7.00, Size: Not available, Color: Not available
# Page: 1, Product Name: Aim Analog Watch, Price: $45.00, Size: Not available, Color: Not available
# Page: 1, Product Name: Ajax Full-Zip Sweatshirt, Price: $69.00, Size: XS, S, M, L, XL, Color: Blue, Green, Red
# Page: 1, Product Name: Ana Running Short, Price: $40.00, Size: 28, 29, 30, 31, 32, Color: Black, Orange, White
# ...

# %% [markdown]
# ### Getting The All Products From All Pages As Table

# %%
from prettytable import PrettyTable

table = PrettyTable()
table.field_names = ["Page", "Product Name", "Price", "Size", "Color"]

# Loop through 12 pages
for page_num in range(1, 13):
    url = f"https://www.scrapingcourse.com/ecommerce/page/{page_num}/"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    products = soup.find_all('li', {'class': 'product'})
    for product in products:
        name = product.find('h2', {'class': 'product-name'}).text
        url_product = product.find('a', href=True)['href']
        price = product.find('span', {'class': 'amount'}).text

        # Fetch hidden elements (size and color) for each product
        response_hidden = requests.get(url_product)
        soup_hid = BeautifulSoup(response_hidden.content, "html.parser")

        additional_info_div = soup_hid.select_one(".woocommerce-Tabs-panel--additional_information")
        
        size = "Not available"
        color = "Not available"
        
        if additional_info_div:
            size_info = additional_info_div.find("tr", {'class': 'woocommerce-product-attributes-item--attribute_size'})
            color_info = additional_info_div.find("tr", {'class': 'woocommerce-product-attributes-item--attribute_color'})
            
            if size_info:
                size = size_info.find('td').text.strip()
            if color_info:
                color = color_info.find('td').text.strip()

        table.add_row([page_num, name, price, size, color])

print(table)
# Out:
# +------+------------------------------------------+--------+--------------------+----------------------------------+
# | Page |               Product Name               | Price  |        Size        |              Color               |
# +------+------------------------------------------+--------+--------------------+----------------------------------+
# |  1   |            Abominable Hoodie             | $69.00 |  XS, S, M, L, XL   |         Blue, Green, Red         |
# |  1   |           Adrienne Trek Jacket           | $57.00 |  XS, S, M, L, XL   |       Gray, Orange, Purple       |
# |  1   |                Aeon Capri                | $48.00 |       28, 29       |       Black, Blue, Orange        |
# |  1   |          Aero Daily Fitness Tee          | $24.00 |  XS, S, M, L, XL   |       Black, Brown, Yellow       |
# |  1   |             Aether Gym Pant              | $74.00 |   32, 33, 34, 36   |        Blue, Brown, Green        |
# ...

# %% [markdown]
# ### Getting The All Products From All Pages As Data Frame

# %%
import pandas as pd

# Create an empty list to store all product data
data_list = []

# Loop through 12 pages
for page_num in range(1, 13):
    url = f"https://www.scrapingcourse.com/ecommerce/page/{page_num}/"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    products = soup.find_all('li', {'class': 'product'})
    for product in products:
        name = product.find('h2', {'class': 'product-name'}).text
        url_product = product.find('a', href=True)['href']
        price = product.find('span', {'class': 'amount'}).text

        # Fetch hidden elements (size and color) for each product
        response_hidden = requests.get(url_product)
        soup_hid = BeautifulSoup(response_hidden.content, "html.parser")

        additional_info_div = soup_hid.select_one(".woocommerce-Tabs-panel--additional_information")

        size = "Not available"
        color = "Not available"

        if additional_info_div:
            size_info = additional_info_div.find("tr", {'class': 'woocommerce-product-attributes-item--attribute_size'})
            color_info = additional_info_div.find("tr", {'class': 'woocommerce-product-attributes-item--attribute_color'})

            if size_info:
                size = size_info.find('td').text.strip()
            if color_info:
                color = color_info.find('td').text.strip()

        # Add the product data to the list
        data_list.append({
            "Page": page_num,
            "Product Name": name,
            "Price": price,
            "Size": size,
            "Color": color
        })

# Convert the list of data to a dataframe
df = pd.concat([pd.DataFrame([data]) for data in data_list], ignore_index=True)

# Save the dataframe to a CSV file
#df.to_csv('product_data.csv', index=False)

print("Data has been successfully written to product_data.csv as a dataframe.")
df
# Out:
# Data has been successfully written to product_data.csv as a dataframe.
#      Page            Product Name   Price             Size  \
# 0       1       Abominable Hoodie  $69.00  XS, S, M, L, XL
# 1       1    Adrienne Trek Jacket  $57.00  XS, S, M, L, XL
# 2       1              Aeon Capri  $48.00           28, 29
# 3       1  Aero Daily Fitness Tee  $24.00  XS, S, M, L, XL
# 4       1         Aether Gym Pant  $74.00   32, 33, 34, 36
# ..    ...                     ...     ...              ...
# 183    12  Wayfarer Messenger Bag  $45.00    Not available
# 184    12      Zeppelin Yoga Pant  $82.00   32, 33, 34, 36
# 185    12          Zing Jump Rope  $12.00    Not available
# 186    12                Zoe Tank  $29.00  XS, S, M, L, XL
# 187    12          Zoltan Gym Tee  $29.00  XS, S, M, L, XL
#
#                      Color
# 0         Blue, Green, Red
# 1     Gray, Orange, Purple
# 2      Black, Blue, Orange
# 3     Black, Brown, Yellow
# 4       Blue, Brown, Green
# ...

# %% [markdown]
# # Dynamic Web Page Scraping With Python

# %% [markdown]
# ## What Is a Dynamic Website?

# %% [markdown]
# A dynamic website doesn't have all its content directly in static HTML. It displays data on the fly using server-side or client-side rendering or based on the user's actions, such as showing more content as the user clicks a button or scrolls down the page (infinite scrolling).
#
# This approach improves user experience by providing relevant content without reloading the entire page. One way to determine if a website is dynamic is to disable JavaScript in your browser's command palette. If the website is dynamic, most or all of its content will disappear.
#
# Not all dynamic pages are the same. Some fetch content from application programming interfaces (APIs), which you can observe through the DevTools' Network tab. Others use client-side rendering to load content directly from JSON objects stored within the DOM (Document Object Model).

# %% [markdown]
# ## Intercept Network Fetch/XHR Requests

# %% [markdown]
# HTTP clients like the Requests don't support JavaScript rendering. When you use Requests and BeautifulSoup to scrape a dynamic site like the infinite scroll challenge page, it only returns the content appearing within the viewport and not those hidden behind the scrollbar.

# %% [markdown]
# The only way to scrape dynamic data with Requests is to intercept the Fetch/XHR request via the Network tab.

# %% [markdown]
# To do that, open the target website via a browser like Chrome. Right-click anywhere to open the DevTools. Then, go to the Network tab.

# %% [markdown]
# Intercepting XHR/Fetch requests during scraping involves inspecting the browser's Network tab to identify the API endpoint supplying the dynamic content. Once the endpoint is identified, you can directly request data from that API using an HTTP client, such as the Requests library. Once you get the API's HTML response, you can parse it using BeautifulSoup.

# %% [markdown]
# The shortcoming of this approach is that it doesn't work for client-side dynamic rendering, where the data is stored as a JSON within the DOM. Not to mention that mimicking an API request is unscalable due to issues like API changes, rate limiting, authentication requirements, etc.

# %% [markdown]
# **HTTP clients like the Requests** don't support **JavaScript** rendering. When you use Requests and BeautifulSoup to scrape a dynamic site like the infinite scroll challenge page, it only returns the content appearing within the viewport and not those hidden behind the scrollbar.

# %% [markdown]
# traditional HTTP clients like Requests don't execute JavaScript, so they only retrieve the static HTML that is loaded when the page first loads. This means any content that is dynamically loaded via JavaScript (such as content from infinite scroll or dynamically updated portions of the page) won't be captured.
#
# The explanation you mentioned is about intercepting XHR (XMLHttpRequest) or Fetch requests:
#
# 1. When a browser loads a dynamic site, it often makes additional requests to an API to fetch more content. By inspecting the Network tab in your browser's developer tools, you can see these requests and identify the API endpoints.
#
# 2. Once you've found the endpoint that provides the dynamic content, you can make direct requests to this endpoint using an HTTP client like Requests.
#
# 3. The data received from the API can be parsed with BeautifulSoup if it contains HTML, or you may need other libraries like json for handling JSON responses.
#
# This method allows you to bypass the JavaScript execution and directly access the data you need.

# %% [markdown]
# https://www.zenrows.com/blog/dynamic-web-pages-scraping-python#dynamic-webscraping-using-beautifulsoup

# %% [markdown]
# Once in the Network tab, reload the page. You'll see several requests in the tab, including image, CSS, JavaScript, content requests, etc.
#
# Scroll through the page, and new requests will appear in the Network tab, showing that each scrolled height triggers a request for fresh content.
#
# For some websites, the API call is usually in a named document icon (this can be different on other websites). In this case, it's in a request named products?offset=0.

# %% [markdown]
# Keep scrolling, and you'll see that the value of offset increases by 10 per scroll height. That value shows 150 when you reach the bottom of the page, indicating the API offsets 10 products 15 times.
#
# Observe the Request URL in the Headers tab. As shown in the above image, it has the following pattern:
# https://www.scrapingcourse.com/ajax/products?offset=150
# This URL shows three essential parts:
# 1. https://www.scrapingcourse.com: Represents the API's base URL.
# 2. ajax/products: The API's endpoint, which theoretically calls the infinite-scroll page.
# 3. offset: A request parameter that determines the number of content the API returns per scroll height.
#
# We'll send requests directly to that API to extract the desired product data. Let's write our scraping logic based on this information.

# %% [markdown]
# ## Scrape the First Few Data

# %%
# specify the API URL without the offset
target_url = "https://www.scrapingcourse.com/infinite-scrolling"

# %% [markdown]
# Define a scraper function that accepts a url parameter.
#
# This function requests the target URL before parsing the returned HTML with BeautifulSoup. It then extracts all the parent elements and loops through them to scrape individual product names and prices using their class selectors:

# %%
def scraper(url):

    # request the target website
    response = requests.get(url)

    # verify the response status
    if response.status_code != 200:
        return f"status failed with {response.status_code}"
    else:

        # parse the HTML content
        soup = BeautifulSoup(response.text, "html.parser")

        # empty list to collect data
        scraped_data = []

        # get the product containers
        products = soup.find_all("div", class_="product-item")

        # iterate through the product containers and extract the product content
        for product in products:
            name_tag = product.find(class_="product-name")
            price_tag = product.find(class_="product-price")

            data = {
                "name": name_tag.text if name_tag else "",
                "price": price_tag.text if price_tag else "",
            }

            # append the data to the empty list
            scraped_data.append(data)
        # return the scraped data
        return scraped_data

# %% [markdown]
# **The code outputs only the first few products:**

# %%
print(scraper(target_url))
# Out:
# [{'name': 'Chaz Kangeroo Hoodie', 'price': '$52'}, {'name': 'Teton Pullover Hoodie', 'price': '$70'}, {'name': 'Bruno Compete Hoodie', 'price': '$63'}, {'name': 'Frankie  Sweatshirt', 'price': '$60'}, {'name': 'Hollister Backyard Sweatshirt', 'price': '$52'}, {'name': 'Stark Fundamental Hoodie', 'price': '$42'}, {'name': 'Hero Hoodie', 'price': '$54'}, {'name': 'Oslo Trek Hoodie', 'price': '$42'}, {'name': 'Abominable Hoodie', 'price': '$69'}, {'name': 'Mach Street Sweatshirt', 'price': '$62'}, {'name': 'Grayson Crewneck Sweatshirt', 'price': '$64'}, {'name': 'Ajax Full-Zip Sweatshirt', 'price': '$69'}]

# %% [markdown]
# **That's only some of the data on that page. Many more are inaccessible due to forced infinite scrolling.**
#
# **So, how can you get all the data out? You need to spoof the API data offset as it appears in the Network tab. We'll do that in the next step.**

# %% [markdown]
# ## Simulate the Network API Call

# %% [markdown]
# The next step is to **simulate the offset logic.** In web scraping, **offset logic** is used to navigate through a large set of data spread across multiple pages. Specify an offset count (offset_count) and set its initial value as zero. Then, define an empty list to extend the data returned by the scraper function:

# %%
# set an initial request count
offset_count = 0

# array to collect scraped data
product_data = []

# %% [markdown]
# Remember that the **API offsets 10 items for 15 scroll heights (150 offsets).**
#
# So, **create a 15-count iteration** using a for loop and increment offset_count by 10 per iteration. Add the increasing offset_count to the API URL using the offset parameter.
#
# **Execute the scraper function with the new URL** and extend the extracted data to the **product_data list:**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# specify the target URL
target_url = "https://www.scrapingcourse.com/ajax/products"

def scraper(url):

    # request the target website
    response = requests.get(url)

    # verify the response status
    if response.status_code != 200:
        return f"status failed with {response.status_code}"
    else:

        # parse the HTML content
        soup = BeautifulSoup(response.text, "html.parser")

        # empty list to collect data
        scraped_data = []

        # get the product containers
        products = soup.find_all("div", class_="product-item")

        # iterate through the product containers and extract the product content
        for product in products:
            name_tag = product.find(class_="product-name")
            price_tag = product.find(class_="product-price")

            data = {
                "name": name_tag.text if name_tag else "",
                "price": price_tag.text if price_tag else "",
            }

            # append the data to the empty list
            scraped_data.append(data)

        # return the scraped data
        return scraped_data

# set an initial request count
offset_count = 0

# array to collect scraped data
product_data = []

# scrape infinite scroll by intercepting API request
# in the Network tab (150 offsets/10 = 15 offsets)
for page in range(0, 15):

    # simulate the full URL format
    requested_page_url = f"{target_url}?offset={offset_count}"

    # execute the scraper function
    collected_data = scraper(requested_page_url)

    # extend the new list with the scraped data
    product_data.extend(collected_data)

    # increment the request count
    offset_count += 10

#print(product_data)

# Convert the list of data to a dataframe
df = pd.concat([pd.DataFrame([data]) for data in product_data], ignore_index=True)
df
# Out:
#                               name price
# 0             Chaz Kangeroo Hoodie   $52
# 1            Teton Pullover Hoodie   $70
# 2             Bruno Compete Hoodie   $63
# 3              Frankie  Sweatshirt   $60
# 4    Hollister Backyard Sweatshirt   $52
# ..                             ...   ...
# 170                  Leah Yoga Top   $39
# 171             Chloe Compete Tank   $39
# 172                     Maya Tunic   $29
# 173             Antonia Racer Tank   $34
# 174              Breathe-Easy Tank   $34
#
# [175 rows x 2 columns]

# %% [markdown]
# **That's it!** You just used Requests and BeautifulSoup to scrape a dynamic page that renders content with infinite scrolling.

# %% [markdown]
# # Scraping Dynamic Web Pages in Python Using Selenium

# %% [markdown]
# Selenium lets you automate the browser, it provides full-scale support for JavaScript rendering.
#
# The pages uses client-side rendering and only load content after some time, making a browser automation tool like Selenium more suitable for scraping.

# %% [markdown]
# Dynamic Web Page and Infınıte Scrolling are different things. While infinite scrolling is a feature you might find on dynamic web pages, it represents only one way in which a page can be dynamic.
# Headless browsers like Selenium and Playwright lift most of the restrictions of dynamic web scraping, allowing for greater flexibility and access to content. However, they can be slow and performance-intensive, and there's still the risk of getting blocked by websites' protection systems.

# %% [markdown]
# To extract data from dynamic-content sites in Python, you can use requests-html. That's a project created by the author of requests that adds the ability to run JavaScript. Another choice is Selenium, the most popular headless browser library.

# %% [markdown]
# For those unfamiliar with the concept, a headless browser is one without a graphical user interface (GUI). With libraries like Selenium, you can instruct it to run tasks. They make for an ideal solution to run JavaScript code in Python!

# %% [markdown]
# To demonstrate **Selenium's** browser capability, let's compare how it handles that website against how an **HTTP client like the Requests library** does.
#
# **Let's first access it with Requests:**

# %%
# pip3 install requests beautifulsoup4
import requests
from bs4 import BeautifulSoup

# specify the target URL
target_url = "https://www.scrapingcourse.com/javascript-rendering"

def scraper(url):

    # request the target website
    response = requests.get(url)

    # verify the response status
    if response.status_code != 200:
        return f"status failed with {response.status_code}"
    else:

        # parse the HTML content
        soup = BeautifulSoup(response.text, "html.parser")

        print(soup.prettify())


# execute the function
scraper(target_url)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    JS Rendering Challenge to Learn Web Scraping - ScrapingCourse.com
#   </title>
#   <!-- Bootstrap CSS -->
#   <link href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" rel="stylesheet"/>
#   <script async="" defer="" src="https://challenges.cloudflare.com/turnstile/v0/api.js">
#   </script>
#   <!-- Google tag (gtag.js) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-NZGD14H87G">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#         gtag('config', 'G-NZGD14H87G');
#   </script>
#   <link as="style" href="https://www.scrapingcourse.com/build/assets/app-5Cdbk7yA.css" rel="preload">
# ...

# %% [markdown]
# The **HTML** returned by the Requests library doesn't contain any product content, showing it can't handle client-side JavaScript rendering:

# %% [markdown]
# However, **Selenium** renders that page successfully and extracts its content. Try it with the following Selenium scraper:

# %%
# pip3 install selenium
from selenium import webdriver

# instantiate options for Chrome
options = webdriver.ChromeOptions()

# run the browser in headless mode
options.add_argument("--headless=new")

# instantiate Chrome WebDriver with options
driver = webdriver.Chrome(options=options)

# URL of the web page to scrape
url = "https://www.scrapingcourse.com/javascript-rendering"

# open the specified URL in the browser
driver.get(url)

# print the page source
print(driver.page_source)

# close the browser
driver.quit()
# Out:
# <html lang="en"><head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>JS Rendering Challenge to Learn Web Scraping - ScrapingCourse.com</title>
#
#     <!-- Bootstrap CSS -->
#     <link href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" rel="stylesheet">
#     <script src="https://challenges.cloudflare.com/turnstile/v0/api.js" async="" defer=""></script>
#     <!-- Google tag (gtag.js) -->
#     <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-NZGD14H87G"></script>
#     <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#         gtag('config', 'G-NZGD14H87G');
#     </script>
# ...

# %% [markdown]
# In addition to built-in JavaScript rendering support, **Selenium lets you execute user interactions within a browser environment, such as clicking, scrolling, typing, hovering, and more.**

# %% [markdown]
# ## Selecting Elements in Selenium

# %% [markdown]
# There are different ways to access elements in Selenium. We've discussed this topic in depth in our [web scraping with Selenium in Python](https://www.zenrows.com/blog/selenium-python-web-scraping#wait-for-page) guide. You can select elements in Selenium using CSS selectors, tag names, XPath, class, or ID.
#
# Let's build a Selenium scraper to collect product data from the previous [infinite scroll challenge page](https://www.scrapingcourse.com/infinite-scrolling). Again, let's quickly inspect the target page elements before extracting its content.
#
# Right-click the first product and select Inspect. We'll still scrape the previous target elements (product names and prices).

# %%
# pip install selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import time


def scraper(driver):

    # find elements by class name 'product-name'
    products = driver.find_elements(By.CLASS_NAME, "product-item")

    scraped_data = []

    # iterate over found elements and print their text content
    for product in products:
        product_name = product.find_element(By.CLASS_NAME, "product-name")
        product_price = product.find_element(By.CLASS_NAME, "product-price")

        data = {
            "name": product_name.text,
            "price": product_price.text,
        }

        # append the data to the empty list
        scraped_data.append(data)

    # return the scraped data
    return scraped_data

# instantiate options for Chrome
options = webdriver.ChromeOptions()

# run the browser in headless mode
options.add_argument("--headless=new")

# instantiate Chrome WebDriver with options
driver = webdriver.Chrome(options=options)

# open the specified URL in the browser
driver.get("https://www.scrapingcourse.com/infinite-scrolling")

# execute the scraper function and print the scraped data
print(scraper(driver))

# close the browser
driver.quit()
# Out:
# [{'name': 'Chaz Kangeroo Hoodie', 'price': '$52'}, {'name': 'Teton Pullover Hoodie', 'price': '$70'}, {'name': 'Bruno Compete Hoodie', 'price': '$63'}, {'name': 'Frankie Sweatshirt', 'price': '$60'}, {'name': 'Hollister Backyard Sweatshirt', 'price': '$52'}, {'name': 'Stark Fundamental Hoodie', 'price': '$42'}, {'name': 'Hero Hoodie', 'price': '$54'}, {'name': 'Oslo Trek Hoodie', 'price': '$42'}, {'name': 'Abominable Hoodie', 'price': '$69'}, {'name': 'Mach Street Sweatshirt', 'price': '$62'}, {'name': 'Grayson Crewneck Sweatshirt', 'price': '$64'}, {'name': 'Ajax Full-Zip Sweatshirt', 'price': '$69'}]

# %% [markdown]
# The above data is fewer than the products on the infinite scroll page. Other products are behind the scroll bar, and you can only access them if you scroll.
#
# How can you automate infinite scrolling with Selenium? Find out in the next section.

# %% [markdown]
# ## How to Scrape Infinite Scroll Web Pages With Selenium

# %% [markdown]
# Scraping all products from the previous [infinite scroll challenge page](https://www.scrapingcourse.com/infinite-scrolling) with Selenium requires automating the scroll action through JavaScript execution.
#
# Let's extend the previous scraper to see how it works.
#
# To automate infinite scrolling with Selenium, obtain the initial page height using the execute_script function. Start a while loop and scroll down to the next height. Then, update the previous height to the current one. Only execute the scraper function when the last and current height values are equal (once you reach the bottom of the page):

# %%
# pip3 install selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

def scraper(driver):

    # find elements by class name 'product-name'
    products = driver.find_elements(By.CLASS_NAME, "product-item")

    scraped_data = []

    # iterate over found elements and print their text content
    for product in products:
        product_name = product.find_element(By.CLASS_NAME, "product-name")
        product_price = product.find_element(By.CLASS_NAME, "product-price")

        data = {
            "name": product_name.text,
            "price": product_price.text,
        }

        # append the data to the empty list
        scraped_data.append(data)

    # return the scraped data
    return scraped_data


# instantiate options for Chrome
options = webdriver.ChromeOptions()

# run the browser in headless mode
options.add_argument("--headless=new")

# instantiate Chrome WebDriver with options
driver = webdriver.Chrome(options=options)

# open the specified URL in the browser
driver.get("https://www.scrapingcourse.com/infinite-scrolling")

# get the previous height value
last_height = driver.execute_script("return document.body.scrollHeight")

# array to collect scraped data
product_data = []

while True:
    # scroll down to the bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # wait for the page to load
    time.sleep(2)

    # get the new height and compare it with the last height
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        # extract data once all content has loaded
        product_data.extend(scraper(driver))
        break
    last_height = new_height

# print the scraped data after scrolling
#print(product_data)

# Convert the list of data to a dataframe
df = pd.concat([pd.DataFrame([data]) for data in product_data], ignore_index=True)

# close the browser
driver.quit()

# %%
df
# Out:
#                               name price
# 0             Chaz Kangeroo Hoodie   $52
# 1            Teton Pullover Hoodie   $70
# 2             Bruno Compete Hoodie   $63
# 3               Frankie Sweatshirt   $60
# 4    Hollister Backyard Sweatshirt   $52
# ..                             ...   ...
# 182                  Leah Yoga Top   $39
# 183             Chloe Compete Tank   $39
# 184                     Maya Tunic   $29
# 185             Antonia Racer Tank   $34
# 186              Breathe-Easy Tank   $34
#
# [187 rows x 2 columns]

# %%
# pip3 install selenium requests beautifulsoup4
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup

def scraper(driver):

    # find elements by class name 'product-item'
    products = driver.find_elements(By.CLASS_NAME, "product-item")

    scraped_data = []

    # iterate over found elements and print their text content
    for product in products:
        product_name = product.find_element(By.CLASS_NAME, "product-name")
        product_price = product.find_element(By.CLASS_NAME, "product-price")
        product_url = product.find_element(By.TAG_NAME, "a").get_attribute("href")  # Get the URL of the product page

        # Fetch hidden elements (size and color) for each product
        response_hidden = requests.get(product_url)
        soup_hid = BeautifulSoup(response_hidden.content, "html.parser")

        additional_info_div = soup_hid.select_one(".woocommerce-Tabs-panel--additional_information")

        size = "Not available"
        color = "Not available"

        if additional_info_div:
            size_info = additional_info_div.find("tr", {'class': 'woocommerce-product-attributes-item--attribute_size'})
            color_info = additional_info_div.find("tr", {'class': 'woocommerce-product-attributes-item--attribute_color'})

            if size_info:
                size = size_info.find('td').text.strip()
            if color_info:
                color = color_info.find('td').text.strip()

        data = {
            "name": product_name.text,
            "price": product_price.text,
            "size": size,
            "color": color
        }

        # append the data to the empty list
        scraped_data.append(data)

    # return the scraped data
    return scraped_data

# instantiate options for Chrome
options = webdriver.ChromeOptions()

# run the browser in headless mode
options.add_argument("--headless=new")

# instantiate Chrome WebDriver with options
driver = webdriver.Chrome(options=options)

# open the specified URL in the browser
driver.get("https://www.scrapingcourse.com/infinite-scrolling")

# get the previous height value
last_height = driver.execute_script("return document.body.scrollHeight")

# array to collect scraped data
product_data = []

while True:
    # scroll down to the bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # wait for the page to load
    time.sleep(2)

    # get the new height and compare it with the last height
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        # extract data once all content has loaded
        product_data.extend(scraper(driver))
        break
    last_height = new_height

# print the scraped data after scrolling
#print(product_data)

# Convert the list of data to a dataframe
df = pd.concat([pd.DataFrame([data]) for data in product_data], ignore_index=True)

# close the browser
driver.quit()

# %%
df
# Out:
#                               name price             size  \
# 0             Chaz Kangeroo Hoodie   $52  XS, S, M, L, XL
# 1            Teton Pullover Hoodie   $70  XS, S, M, L, XL
# 2             Bruno Compete Hoodie   $63  XS, S, M, L, XL
# 3               Frankie Sweatshirt   $60  XS, S, M, L, XL
# 4    Hollister Backyard Sweatshirt   $52  XS, S, M, L, XL
# ..                             ...   ...              ...
# 182                  Leah Yoga Top   $39  XS, S, M, L, XL
# 183             Chloe Compete Tank   $39  XS, S, M, L, XL
# 184                     Maya Tunic   $29  XS, S, M, L, XL
# 185             Antonia Racer Tank   $34  XS, S, M, L, XL
# 186              Breathe-Easy Tank   $34  XS, S, M, L, XL
#
#                      color
# 0      Black, Gray, Orange
# 1       Black, Purple, Red
# 2       Black, Blue, Green
# 3     Green, White, Yellow
# 4        Green, Red, White
# ..                     ...
# 182  Orange, Purple, White
# 183      Blue, Red, Yellow
# ...

# %% [markdown]
# There you go 🎉! You've used Selenium to automate infinite scrolling and scrape a dynamic web page without scrolling limitations.
#
# **NOTE!**
# - Using Selenium for dynamic web scraping can get tricky with continuous [Selenium updates](https://www.selenium.dev/categories/releases/). It's important to stay informed about the latest changes.

# %%
products_n = soup.find_all("div", class_="product-item")
# Loop through each product item 
for product in products_n: 
    # Find the span with class "product-name" within the product item 
    product_name = product.find("span", class_="product-name") 
    # Check if the span was found and print the text content 
    if product_name: print(product_name.text)

# %%
products_n
# Out:
# []

# %%
# Find all classes within the product item
product_classes = product.get('class')
if product_classes:
    print("Classes within the product item:", product_classes)
# Out:
# Classes within the product item: ['product-item', 'flex', 'flex-col', 'items-center', 'rounded-lg']

# %%
# Loop through each product item
for product in products:
    # Find the span with class "product-name" within the product item
    product_name = product.find("span", class_="product-name")
    # Check if the span was found and if the text content matches "Chaz Kangeroo Hoodie"
    if product_name and product_name.text == "Chaz Kangeroo Hoodie":
        print(product_name.text)
# Out:
# Chaz Kangeroo Hoodie
