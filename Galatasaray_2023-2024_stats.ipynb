# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd

# %%
df = pd.read_html('https://fbref.com/en/squads/ecd11ca2/2023-2024/c26/Galatasaray-Stats-Super-Lig',
                  attrs={"id":"stats_standard_26"})[0]

# %% [markdown]
# - **Performance_G-PK**, Meaning: Goals minus Penalty Kicks
# - **Performance_PK**, Meaning: Penalty Kicks
# - **Performance_PKatt**, Meaning: Penalty Kick Attempts
# - **Performance_CrdY**, Meaning: Yellow Card
# - **Performance_CrdR**, Meaning: Red Cards

# %%
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0   Fernando Muslera             uy URU                 GK               37.0
# 1     Lucas Torreira             uy URU                 MF               27.0
# 2       Mauro Icardi             ar ARG                 FW               30.0
# 3      Dries Mertens             be BEL                 MF               36.0
# 4     Victor Nelsson             dk DEN                 DF               24.0
#
#   Unnamed: 4_level_0 Playing Time               Performance        ...       \
#                   MP       Starts     Min   90s         Gls   Ast  ...   PK
# 0                 37           37  3299.0  36.7         0.0   0.0  ...  0.0
# 1                 35           35  2972.0  33.0         1.0   2.0  ...  0.0
# 2                 34           31  2855.0  31.7        25.0   8.0  ...  6.0
# ...

# %%
df.columns.values
# Out:
# array([('Unnamed: 0_level_0', 'Player'), ('Unnamed: 1_level_0', 'Nation'),
#        ('Unnamed: 2_level_0', 'Pos'), ('Unnamed: 3_level_0', 'Age'),
#        ('Unnamed: 4_level_0', 'MP'), ('Playing Time', 'Starts'),
#        ('Playing Time', 'Min'), ('Playing Time', '90s'),
#        ('Performance', 'Gls'), ('Performance', 'Ast'),
#        ('Performance', 'G+A'), ('Performance', 'G-PK'),
#        ('Performance', 'PK'), ('Performance', 'PKatt'),
#        ('Performance', 'CrdY'), ('Performance', 'CrdR'),
#        ('Per 90 Minutes', 'Gls'), ('Per 90 Minutes', 'Ast'),
#        ('Per 90 Minutes', 'G+A'), ('Per 90 Minutes', 'G-PK'),
#        ('Per 90 Minutes', 'G+A-PK'), ('Unnamed: 21_level_0', 'Matches')],
#       dtype=object)

# %% [markdown]
# - columns have two items, to transform them having one item and them

# %%
df.columns = ['_'.join(col).strip() for col in df.columns.values]

# %%
df.head(20)
# Out:
#    Unnamed: 0_level_0_Player Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  \
# 0           Fernando Muslera                    uy URU                     GK
# 1             Lucas Torreira                    uy URU                     MF
# 2               Mauro Icardi                    ar ARG                     FW
# 3              Dries Mertens                    be BEL                     MF
# 4             Victor Nelsson                    dk DEN                     DF
# 5           Kerem Aktürkoğlu                    tr TUR                     MF
# 6         Barış Alper Yılmaz                    tr TUR                  MF,DF
# 7             Kerem Demirbay                    de GER                     MF
# 8        Abdülkerim Bardakcı                    tr TUR                     DF
# 9                 Kaan Ayhan                    tr TUR                     DF
# 10                Sacha Boey                    fr FRA                     DF
# ...

# %%
# Clean and rename specific columns 
df.columns = [col.split('_')[-1].lower() if 'Unnamed' in col else col for col in df.columns]

# %%
df.head(24)
# Out:
#                  player  nation    pos   age  mp  Playing Time_Starts  \
# 0      Fernando Muslera  uy URU     GK  37.0  37                   37
# 1        Lucas Torreira  uy URU     MF  27.0  35                   35
# 2          Mauro Icardi  ar ARG     FW  30.0  34                   31
# 3         Dries Mertens  be BEL     MF  36.0  36                   31
# 4        Victor Nelsson  dk DEN     DF  24.0  32                   29
# 5      Kerem Aktürkoğlu  tr TUR     MF  24.0  37                   29
# 6    Barış Alper Yılmaz  tr TUR  MF,DF  23.0  37                   28
# 7        Kerem Demirbay  de GER     MF  30.0  34                   27
# 8   Abdülkerim Bardakcı  tr TUR     DF  28.0  27                   25
# 9            Kaan Ayhan  tr TUR     DF  28.0  35                   21
# 10           Sacha Boey  fr FRA     DF  22.0  19                   19
# 11     Davinson Sánchez  co COL     DF  27.0  23                   17
# ...
